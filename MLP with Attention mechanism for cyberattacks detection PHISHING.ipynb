# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.28.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (60.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: numpy>=1.20 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.23.5)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: packaging in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.12.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (14.0.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\Fer_U\PycharmProjects\CyberattacksAttention\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from pandas) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\Fer_U\PycharmProjects\CyberattacksAttention\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install neural_structured_learning
# Out:
# Requirement already satisfied: neural_structured_learning in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (1.4.0)
# Requirement already satisfied: scipy in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from neural_structured_learning) (1.9.3)
# Requirement already satisfied: absl-py in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from neural_structured_learning) (1.3.0)
# Requirement already satisfied: six in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from neural_structured_learning) (1.16.0)
# Requirement already satisfied: attrs in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from neural_structured_learning) (22.1.0)
# Requirement already satisfied: numpy<1.26.0,>=1.18.5 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from scipy->neural_structured_learning) (1.23.5)
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\Fer_U\PycharmProjects\CyberattacksAttention\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install scikit_learn
# Out:
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\Fer_U\PycharmProjects\CyberattacksAttention\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: scikit_learn in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from scikit_learn) (1.23.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from scikit_learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from scikit_learn) (1.9.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\fer_u\pycharmprojects\cyberattacksattention\venv\lib\site-packages (from scikit_learn) (1.2.0)

# %%
import tensorflow as tf
import pandas as pd
import neural_structured_learning as nsl
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.model_selection import *

# %%
df = pd.read_csv('ICSX_URL_2017/Phishing.csv')

# %%
df.head()
# Out:
#    Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 0            0                   2                12                5.5
# 1            0                   3                12                5.0
# 2            2                   2                11                4.0
# 3            0                   2                 7                4.5
# 4           19                   2                10                6.0
#
#    longdomaintokenlen  avgpathtokenlen  tld  charcompvowels  charcompace  \
# 0                   8         4.083334    2              15            7
# 1                  10         3.583333    3              12            8
# 2                   5         4.750000    2              16           11
# 3                   7         5.714286    2              15           10
# 4                   9         2.250000    2               9            5
#
#    ldl_url  ...  SymbolCount_FileName  SymbolCount_Extension  \
# 0        0  ...                    -1                     -1
# 1        2  ...                     1                      0
# 2        0  ...                     2                      0
# 3        0  ...                     0                      0
# 4        0  ...                     5                      4
#
#    SymbolCount_Afterpath  Entropy_URL  Entropy_Domain  Entropy_DirectoryName  \
# 0                     -1     0.676804        0.860529              -1.000000
# 1                     -1     0.715629        0.776796               0.693127
# 2                      1     0.677701        1.000000               0.677704
# 3                     -1     0.696067        0.879588               0.818007
# 4                      3     0.747202        0.833700               0.655459
#
#    Entropy_Filename  Entropy_Extension  Entropy_Afterpath  URL_Type_obf_Type
# 0         -1.000000           -1.00000          -1.000000             benign
# 1          0.738315            1.00000          -1.000000             benign
# 2          0.916667            0.00000           0.898227             benign
# 3          0.753585            0.00000          -1.000000             benign
# 4          0.829535            0.83615           0.823008             benign
#
# [5 rows x 80 columns]

# %%
features = len(df.columns) - 1
label_encoder = LabelEncoder()
df = df.dropna()
df = df.reset_index(drop=True)
df['URL_Type_obf_Type'] = label_encoder.fit_transform(df['URL_Type_obf_Type'])
classes = df['URL_Type_obf_Type'].nunique()

# %%
df
# Out:
#       Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 0               0                   2                12           5.500000
# 1               0                   3                12           5.000000
# 2              19                   2                10           6.000000
# 3               0                   2                10           5.500000
# 4               0                   2                 9           2.500000
# ...           ...                 ...               ...                ...
# 6718            0                   2                 5           5.500000
# 6719            0                   2                 5           3.500000
# 6720            0                   2                 4           7.000000
# 6721            0                   3                 5           4.666666
# 6722            0                   2                 4           8.000000
#
#       longdomaintokenlen  avgpathtokenlen  tld  charcompvowels  charcompace  \
# 0                      8         4.083334    2              15            7
# 1                     10         3.583333    3              12            8
# 2                      9         2.250000    2               9            5
# 3                      9         4.100000    2              15           11
# 4                      3         4.555555    2               6            3
# ...                  ...              ...  ...             ...          ...
# 6718                   8         2.800000    2               5            1
# 6719                   5         3.600000    2               5            2
# 6720                  12         3.000000    2               4            2
# 6721                  10         2.000000    3               3            2
# 6722                  13         2.500000    2               1            0
#
#       ldl_url  ...  SymbolCount_FileName  SymbolCount_Extension  \
# 0           0  ...                    -1                     -1
# 1           2  ...                     1                      0
# 2           0  ...                     5                      4
# 3           0  ...                    -1                     -1
# 4           0  ...                     1                      0
# ...       ...  ...                   ...                    ...
# 6718        0  ...                     1                      0
# 6719        0  ...                     1                      0
# 6720        0  ...                     1                      0
# 6721        0  ...                     1                      0
# 6722        0  ...                     1                      0
#
#       SymbolCount_Afterpath  Entropy_URL  Entropy_Domain  \
# 0                        -1     0.676804        0.860529
# 1                        -1     0.715629        0.776796
# 2                         3     0.747202        0.833700
# 3                        -1     0.732981        0.860529
# 4                        -1     0.742606        1.000000
# ...                     ...          ...             ...
# 6718                     -1     0.734789        0.953510
# 6719                     -1     0.793129        0.916667
# 6720                     -1     0.797564        0.918863
# 6721                     -1     0.758084        0.906250
# 6722                     -1     0.759976        0.856088
#
#       Entropy_DirectoryName  Entropy_Filename  Entropy_Extension  \
# 0                 -1.000000         -1.000000           -1.00000
# 1                  0.693127          0.738315            1.00000
# 2                  0.655459          0.829535            0.83615
# 3                 -1.000000         -1.000000           -1.00000
# 4                  0.785719          0.808833            1.00000
# ...                     ...               ...                ...
# 6718               0.693127          1.000000            1.00000
# 6719               0.859582          1.000000            1.00000
# 6720               0.871049          1.000000            1.00000
# 6721               0.833333          1.000000            1.00000
# 6722               0.871049          0.898227            0.57938
#
#       Entropy_Afterpath  URL_Type_obf_Type
# 0             -1.000000                  0
# 1             -1.000000                  0
# 2              0.823008                  0
# 3             -1.000000                  0
# 4             -1.000000                  0
# ...                 ...                ...
# 6718          -1.000000                  1
# 6719          -1.000000                  1
# 6720          -1.000000                  1
# 6721          -1.000000                  1
# 6722          -1.000000                  1
#
# [6723 rows x 80 columns]

# %%
df.groupby('URL_Type_obf_Type').count()
# Out:
#                    Querylength  domain_token_count  path_token_count  \
# URL_Type_obf_Type
# 0                         2709                2709              2709
# 1                         4014                4014              4014
#
#                    avgdomaintokenlen  longdomaintokenlen  avgpathtokenlen  \
# URL_Type_obf_Type
# 0                               2709                2709             2709
# 1                               4014                4014             4014
#
#                     tld  charcompvowels  charcompace  ldl_url  ...  \
# URL_Type_obf_Type                                              ...
# 0                  2709            2709         2709     2709  ...
# 1                  4014            4014         4014     4014  ...
#
#                    SymbolCount_Directoryname  SymbolCount_FileName  \
# URL_Type_obf_Type
# 0                                       2709                  2709
# 1                                       4014                  4014
#
#                    SymbolCount_Extension  SymbolCount_Afterpath  Entropy_URL  \
# URL_Type_obf_Type
# 0                                   2709                   2709         2709
# 1                                   4014                   4014         4014
#
#                    Entropy_Domain  Entropy_DirectoryName  Entropy_Filename  \
# URL_Type_obf_Type
# 0                            2709                   2709              2709
# 1                            4014                   4014              4014
#
#                    Entropy_Extension  Entropy_Afterpath
# URL_Type_obf_Type
# 0                               2709               2709
# 1                               4014               4014
#
# [2 rows x 79 columns]

# %%
df_0 = df.loc[df['URL_Type_obf_Type'] == 0]
df_1 = df.loc[df['URL_Type_obf_Type'] == 1]
df_2 = df.loc[df['URL_Type_obf_Type'] == 2]
df_3 = df.loc[df['URL_Type_obf_Type'] == 3]
df_4 = df.loc[df['URL_Type_obf_Type'] == 4]

# %%
df = pd.concat([df_0, df_1, df_2, df_3, df_4])
df
# Out:
#       Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 0               0                   2                12           5.500000
# 1               0                   3                12           5.000000
# 2              19                   2                10           6.000000
# 3               0                   2                10           5.500000
# 4               0                   2                 9           2.500000
# ...           ...                 ...               ...                ...
# 6718            0                   2                 5           5.500000
# 6719            0                   2                 5           3.500000
# 6720            0                   2                 4           7.000000
# 6721            0                   3                 5           4.666666
# 6722            0                   2                 4           8.000000
#
#       longdomaintokenlen  avgpathtokenlen  tld  charcompvowels  charcompace  \
# 0                      8         4.083334    2              15            7
# 1                     10         3.583333    3              12            8
# 2                      9         2.250000    2               9            5
# 3                      9         4.100000    2              15           11
# 4                      3         4.555555    2               6            3
# ...                  ...              ...  ...             ...          ...
# 6718                   8         2.800000    2               5            1
# 6719                   5         3.600000    2               5            2
# 6720                  12         3.000000    2               4            2
# 6721                  10         2.000000    3               3            2
# 6722                  13         2.500000    2               1            0
#
#       ldl_url  ...  SymbolCount_FileName  SymbolCount_Extension  \
# 0           0  ...                    -1                     -1
# 1           2  ...                     1                      0
# 2           0  ...                     5                      4
# 3           0  ...                    -1                     -1
# 4           0  ...                     1                      0
# ...       ...  ...                   ...                    ...
# 6718        0  ...                     1                      0
# 6719        0  ...                     1                      0
# 6720        0  ...                     1                      0
# 6721        0  ...                     1                      0
# 6722        0  ...                     1                      0
#
#       SymbolCount_Afterpath  Entropy_URL  Entropy_Domain  \
# 0                        -1     0.676804        0.860529
# 1                        -1     0.715629        0.776796
# 2                         3     0.747202        0.833700
# 3                        -1     0.732981        0.860529
# 4                        -1     0.742606        1.000000
# ...                     ...          ...             ...
# 6718                     -1     0.734789        0.953510
# 6719                     -1     0.793129        0.916667
# 6720                     -1     0.797564        0.918863
# 6721                     -1     0.758084        0.906250
# 6722                     -1     0.759976        0.856088
#
#       Entropy_DirectoryName  Entropy_Filename  Entropy_Extension  \
# 0                 -1.000000         -1.000000           -1.00000
# 1                  0.693127          0.738315            1.00000
# 2                  0.655459          0.829535            0.83615
# 3                 -1.000000         -1.000000           -1.00000
# 4                  0.785719          0.808833            1.00000
# ...                     ...               ...                ...
# 6718               0.693127          1.000000            1.00000
# 6719               0.859582          1.000000            1.00000
# 6720               0.871049          1.000000            1.00000
# 6721               0.833333          1.000000            1.00000
# 6722               0.871049          0.898227            0.57938
#
#       Entropy_Afterpath  URL_Type_obf_Type
# 0             -1.000000                  0
# 1             -1.000000                  0
# 2              0.823008                  0
# 3             -1.000000                  0
# 4             -1.000000                  0
# ...                 ...                ...
# 6718          -1.000000                  1
# 6719          -1.000000                  1
# 6720          -1.000000                  1
# 6721          -1.000000                  1
# 6722          -1.000000                  1
#
# [6723 rows x 80 columns]

# %%
y = df.pop('URL_Type_obf_Type')
X = df

normalizer_scaler = preprocessing.Normalizer()
x_scaled = normalizer_scaler.fit_transform(X)
X = pd.DataFrame(x_scaled)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train = tf.convert_to_tensor(X_train)
y_train = tf.convert_to_tensor(y_train)

X_test = tf.convert_to_tensor(X_test)
y_test = tf.convert_to_tensor(y_test)

# %%
input = tf.keras.layers.Input((features,), name='feature')

n1 = tf.keras.layers.Dense(32)(input)
n1 = tf.keras.layers.Dropout(0.25)(n1)
n1 = tf.keras.layers.Dense(64)(n1)
n1 = tf.keras.layers.Dropout(0.25)(n1)
n1 = tf.keras.layers.Dense(128)(n1)
n1 = tf.keras.layers.Dropout(0.25)(n1)
n1 = tf.keras.layers.Dense(256)(n1)

n1 = tf.keras.layers.MultiHeadAttention(num_heads=int(256/8), key_dim=256, value_dim=256, attention_axes=1)(n1, n1, n1)

n1 = tf.keras.layers.Dense(256)(n1)
n1 = tf.keras.layers.Dropout(0.25)(n1)
n1 = tf.keras.layers.Dense(128)(n1)
n1 = tf.keras.layers.Dropout(0.25)(n1)
n1 = tf.keras.layers.Dense(64)(n1)
n1 = tf.keras.layers.Dropout(0.25)(n1)
n1 = tf.keras.layers.Dense(32)(n1)

output = tf.keras.layers.Dense(classes, activation='softmax')(n1)

model = tf.keras.Model(inputs=input, outputs=output)

adv_config = nsl.configs.make_adv_reg_config(multiplier=0.2, adv_step_size=0.05)
adv_model = nsl.keras.AdversarialRegularization(model, adv_config=adv_config)

# Compile, train, and evaluate.
adv_model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  feature (InputLayer)           [(None, 79)]         0           []
#
#  dense (Dense)                  (None, 32)           2560        ['feature[0][0]']
#
#  dropout (Dropout)              (None, 32)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 64)           2112        ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 128)          8320        ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 128)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 256)          33024       ['dropout_2[0][0]']
#
#  multi_head_attention (MultiHea  (None, 256)         8413440     ['dense_3[0][0]',
#  dAttention)                                                      'dense_3[0][0]',
#                                                                   'dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 256)          65792       ['multi_head_attention[0][0]']
#
#  dropout_3 (Dropout)            (None, 256)          0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 128)          32896       ['dropout_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 128)          0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 64)           8256        ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 64)           0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 32)           2080        ['dropout_5[0][0]']
#
#  dense_8 (Dense)                (None, 2)            66          ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 8,568,546
# Trainable params: 8,568,546
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, 
                          show_shapes=True,
                          show_dtype=True,
                          show_layer_names=True,
                          rankdir='LR')
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
adv_model.fit({'feature': X_train, 'label': y_train}, epochs=1000, batch_size=512, validation_data={'feature': X_test, 'label': y_test})
# Out:
# Epoch 1/1000
# WARNING:tensorflow:From C:\Users\Fer_U\PycharmProjects\CyberattacksAttention\venv\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:absl:Cannot perturb non-Tensor input: dict_keys(['label'])
# 11/11 [==============================] - 9s 382ms/step - loss: 0.9065 - sparse_categorical_crossentropy: 0.7443 - sparse_categorical_accuracy: 0.6013 - scaled_adversarial_loss: 0.1623 - val_loss: 0.6238 - val_sparse_categorical_crossentropy: 0.4813 - val_sparse_categorical_accuracy: 0.8112 - val_scaled_adversarial_loss: 0.1425
# Epoch 2/1000
# 11/11 [==============================] - 4s 344ms/step - loss: 0.6621 - sparse_categorical_crossentropy: 0.5208 - sparse_categorical_accuracy: 0.7533 - scaled_adversarial_loss: 0.1413 - val_loss: 0.5839 - val_sparse_categorical_crossentropy: 0.4461 - val_sparse_categorical_accuracy: 0.7710 - val_scaled_adversarial_loss: 0.1378
# Epoch 3/1000
# 11/11 [==============================] - 4s 339ms/step - loss: 0.5894 - sparse_categorical_crossentropy: 0.4571 - sparse_categorical_accuracy: 0.7843 - scaled_adversarial_loss: 0.1323 - val_loss: 0.5146 - val_sparse_categorical_crossentropy: 0.3848 - val_sparse_categorical_accuracy: 0.8178 - val_scaled_adversarial_loss: 0.1298
# Epoch 4/1000
# 11/11 [==============================] - 4s 352ms/step - loss: 0.5280 - sparse_categorical_crossentropy: 0.3974 - sparse_categorical_accuracy: 0.8170 - scaled_adversarial_loss: 0.1306 - val_loss: 0.4755 - val_sparse_categorical_crossentropy: 0.3433 - val_sparse_categorical_accuracy: 0.8513 - val_scaled_adversarial_loss: 0.1322
# Epoch 5/1000
# 11/11 [==============================] - 4s 337ms/step - loss: 0.5116 - sparse_categorical_crossentropy: 0.3823 - sparse_categorical_accuracy: 0.8340 - scaled_adversarial_loss: 0.1292 - val_loss: 0.4551 - val_sparse_categorical_crossentropy: 0.3177 - val_sparse_categorical_accuracy: 0.8558 - val_scaled_adversarial_loss: 0.1374
# Epoch 6/1000
# 11/11 [==============================] - 4s 346ms/step - loss: 0.4783 - sparse_categorical_crossentropy: 0.3488 - sparse_categorical_accuracy: 0.8512 - scaled_adversarial_loss: 0.1295 - val_loss: 0.4467 - val_sparse_categorical_crossentropy: 0.3052 - val_sparse_categorical_accuracy: 0.8781 - val_scaled_adversarial_loss: 0.1414
# Epoch 7/1000
# 11/11 [==============================] - 4s 334ms/step - loss: 0.4601 - sparse_categorical_crossentropy: 0.3297 - sparse_categorical_accuracy: 0.8609 - scaled_adversarial_loss: 0.1304 - val_loss: 0.4320 - val_sparse_categorical_crossentropy: 0.2891 - val_sparse_categorical_accuracy: 0.8803 - val_scaled_adversarial_loss: 0.1429
# Epoch 8/1000
# 11/11 [==============================] - 4s 339ms/step - loss: 0.4581 - sparse_categorical_crossentropy: 0.3257 - sparse_categorical_accuracy: 0.8704 - scaled_adversarial_loss: 0.1324 - val_loss: 0.4319 - val_sparse_categorical_crossentropy: 0.2973 - val_sparse_categorical_accuracy: 0.8848 - val_scaled_adversarial_loss: 0.1346
# Epoch 9/1000
# 11/11 [==============================] - 4s 349ms/step - loss: 0.4502 - sparse_categorical_crossentropy: 0.3171 - sparse_categorical_accuracy: 0.8754 - scaled_adversarial_loss: 0.1331 - val_loss: 0.4356 - val_sparse_categorical_crossentropy: 0.3043 - val_sparse_categorical_accuracy: 0.8929 - val_scaled_adversarial_loss: 0.1313
# Epoch 10/1000
# 11/11 [==============================] - 4s 340ms/step - loss: 0.4399 - sparse_categorical_crossentropy: 0.3090 - sparse_categorical_accuracy: 0.8773 - scaled_adversarial_loss: 0.1309 - val_loss: 0.4197 - val_sparse_categorical_crossentropy: 0.2832 - val_sparse_categorical_accuracy: 0.8944 - val_scaled_adversarial_loss: 0.1365
# Epoch 11/1000
# 11/11 [==============================] - 4s 338ms/step - loss: 0.4295 - sparse_categorical_crossentropy: 0.2976 - sparse_categorical_accuracy: 0.8849 - scaled_adversarial_loss: 0.1319 - val_loss: 0.4125 - val_sparse_categorical_crossentropy: 0.2675 - val_sparse_categorical_accuracy: 0.8944 - val_scaled_adversarial_loss: 0.1451
# Epoch 12/1000
# 11/11 [==============================] - 4s 328ms/step - loss: 0.4275 - sparse_categorical_crossentropy: 0.2925 - sparse_categorical_accuracy: 0.8847 - scaled_adversarial_loss: 0.1350 - val_loss: 0.4111 - val_sparse_categorical_crossentropy: 0.2656 - val_sparse_categorical_accuracy: 0.8974 - val_scaled_adversarial_loss: 0.1456
# Epoch 13/1000
# 11/11 [==============================] - 4s 330ms/step - loss: 0.4255 - sparse_categorical_crossentropy: 0.2893 - sparse_categorical_accuracy: 0.8892 - scaled_adversarial_loss: 0.1362 - val_loss: 0.4139 - val_sparse_categorical_crossentropy: 0.2752 - val_sparse_categorical_accuracy: 0.8996 - val_scaled_adversarial_loss: 0.1387
# Epoch 14/1000
# 11/11 [==============================] - 4s 349ms/step - loss: 0.4172 - sparse_categorical_crossentropy: 0.2830 - sparse_categorical_accuracy: 0.8896 - scaled_adversarial_loss: 0.1342 - val_loss: 0.4269 - val_sparse_categorical_crossentropy: 0.2870 - val_sparse_categorical_accuracy: 0.8706 - val_scaled_adversarial_loss: 0.1399
# Epoch 15/1000
# 11/11 [==============================] - 4s 335ms/step - loss: 0.4122 - sparse_categorical_crossentropy: 0.2781 - sparse_categorical_accuracy: 0.8907 - scaled_adversarial_loss: 0.1341 - val_loss: 0.4054 - val_sparse_categorical_crossentropy: 0.2473 - val_sparse_categorical_accuracy: 0.8952 - val_scaled_adversarial_loss: 0.1581
# Epoch 16/1000
# 11/11 [==============================] - 4s 338ms/step - loss: 0.4088 - sparse_categorical_crossentropy: 0.2709 - sparse_categorical_accuracy: 0.8933 - scaled_adversarial_loss: 0.1379 - val_loss: 0.4091 - val_sparse_categorical_crossentropy: 0.2430 - val_sparse_categorical_accuracy: 0.8989 - val_scaled_adversarial_loss: 0.1661
# Epoch 17/1000
# 11/11 [==============================] - 4s 346ms/step - loss: 0.4173 - sparse_categorical_crossentropy: 0.2760 - sparse_categorical_accuracy: 0.8953 - scaled_adversarial_loss: 0.1413 - val_loss: 0.4029 - val_sparse_categorical_crossentropy: 0.2424 - val_sparse_categorical_accuracy: 0.8996 - val_scaled_adversarial_loss: 0.1605
# Epoch 18/1000
# 11/11 [==============================] - 4s 359ms/step - loss: 0.4055 - sparse_categorical_crossentropy: 0.2668 - sparse_categorical_accuracy: 0.8970 - scaled_adversarial_loss: 0.1386 - val_loss: 0.4037 - val_sparse_categorical_crossentropy: 0.2515 - val_sparse_categorical_accuracy: 0.8967 - val_scaled_adversarial_loss: 0.1522
# Epoch 19/1000
# 11/11 [==============================] - 4s 351ms/step - loss: 0.4027 - sparse_categorical_crossentropy: 0.2655 - sparse_categorical_accuracy: 0.8974 - scaled_adversarial_loss: 0.1372 - val_loss: 0.4019 - val_sparse_categorical_crossentropy: 0.2405 - val_sparse_categorical_accuracy: 0.8989 - val_scaled_adversarial_loss: 0.1614
# Epoch 20/1000
# 11/11 [==============================] - 4s 353ms/step - loss: 0.4065 - sparse_categorical_crossentropy: 0.2665 - sparse_categorical_accuracy: 0.8975 - scaled_adversarial_loss: 0.1400 - val_loss: 0.4028 - val_sparse_categorical_crossentropy: 0.2587 - val_sparse_categorical_accuracy: 0.8981 - val_scaled_adversarial_loss: 0.1441
# Epoch 21/1000
# 11/11 [==============================] - 4s 340ms/step - loss: 0.4046 - sparse_categorical_crossentropy: 0.2654 - sparse_categorical_accuracy: 0.9009 - scaled_adversarial_loss: 0.1392 - val_loss: 0.3988 - val_sparse_categorical_crossentropy: 0.2431 - val_sparse_categorical_accuracy: 0.8989 - val_scaled_adversarial_loss: 0.1557
# Epoch 22/1000
# 11/11 [==============================] - 4s 329ms/step - loss: 0.4022 - sparse_categorical_crossentropy: 0.2605 - sparse_categorical_accuracy: 0.8998 - scaled_adversarial_loss: 0.1416 - val_loss: 0.3980 - val_sparse_categorical_crossentropy: 0.2480 - val_sparse_categorical_accuracy: 0.8967 - val_scaled_adversarial_loss: 0.1500
# Epoch 23/1000
# 11/11 [==============================] - 4s 328ms/step - loss: 0.3981 - sparse_categorical_crossentropy: 0.2559 - sparse_categorical_accuracy: 0.9026 - scaled_adversarial_loss: 0.1422 - val_loss: 0.3968 - val_sparse_categorical_crossentropy: 0.2463 - val_sparse_categorical_accuracy: 0.9004 - val_scaled_adversarial_loss: 0.1505
# Epoch 24/1000
# 11/11 [==============================] - 4s 330ms/step - loss: 0.3997 - sparse_categorical_crossentropy: 0.2558 - sparse_categorical_accuracy: 0.9048 - scaled_adversarial_loss: 0.1439 - val_loss: 0.3953 - val_sparse_categorical_crossentropy: 0.2346 - val_sparse_categorical_accuracy: 0.9019 - val_scaled_adversarial_loss: 0.1607
# Epoch 25/1000
# 11/11 [==============================] - 4s 331ms/step - loss: 0.4001 - sparse_categorical_crossentropy: 0.2567 - sparse_categorical_accuracy: 0.8981 - scaled_adversarial_loss: 0.1435 - val_loss: 0.4030 - val_sparse_categorical_crossentropy: 0.2537 - val_sparse_categorical_accuracy: 0.8996 - val_scaled_adversarial_loss: 0.1493
# Epoch 26/1000
# 11/11 [==============================] - 4s 335ms/step - loss: 0.4076 - sparse_categorical_crossentropy: 0.2661 - sparse_categorical_accuracy: 0.8998 - scaled_adversarial_loss: 0.1415 - val_loss: 0.3963 - val_sparse_categorical_crossentropy: 0.2363 - val_sparse_categorical_accuracy: 0.9033 - val_scaled_adversarial_loss: 0.1600
# Epoch 27/1000
# 11/11 [==============================] - 4s 332ms/step - loss: 0.3923 - sparse_categorical_crossentropy: 0.2508 - sparse_categorical_accuracy: 0.9039 - scaled_adversarial_loss: 0.1416 - val_loss: 0.3947 - val_sparse_categorical_crossentropy: 0.2374 - val_sparse_categorical_accuracy: 0.9056 - val_scaled_adversarial_loss: 0.1573
# Epoch 28/1000
# 11/11 [==============================] - 4s 339ms/step - loss: 0.3986 - sparse_categorical_crossentropy: 0.2503 - sparse_categorical_accuracy: 0.9052 - scaled_adversarial_loss: 0.1483 - val_loss: 0.3945 - val_sparse_categorical_crossentropy: 0.2401 - val_sparse_categorical_accuracy: 0.9048 - val_scaled_adversarial_loss: 0.1544
# Epoch 29/1000
# 11/11 [==============================] - 4s 341ms/step - loss: 0.3941 - sparse_categorical_crossentropy: 0.2512 - sparse_categorical_accuracy: 0.9028 - scaled_adversarial_loss: 0.1428 - val_loss: 0.3954 - val_sparse_categorical_crossentropy: 0.2449 - val_sparse_categorical_accuracy: 0.9056 - val_scaled_adversarial_loss: 0.1505
# Epoch 30/1000
# 11/11 [==============================] - 4s 333ms/step - loss: 0.3945 - sparse_categorical_crossentropy: 0.2490 - sparse_categorical_accuracy: 0.9065 - scaled_adversarial_loss: 0.1455 - val_loss: 0.3969 - val_sparse_categorical_crossentropy: 0.2270 - val_sparse_categorical_accuracy: 0.9152 - val_scaled_adversarial_loss: 0.1699
# Epoch 31/1000
# 11/11 [==============================] - 4s 337ms/step - loss: 0.4013 - sparse_categorical_crossentropy: 0.2521 - sparse_categorical_accuracy: 0.9057 - scaled_adversarial_loss: 0.1492 - val_loss: 0.4031 - val_sparse_categorical_crossentropy: 0.2589 - val_sparse_categorical_accuracy: 0.9019 - val_scaled_adversarial_loss: 0.1442
# Epoch 32/1000
# 11/11 [==============================] - 4s 332ms/step - loss: 0.4039 - sparse_categorical_crossentropy: 0.2630 - sparse_categorical_accuracy: 0.9033 - scaled_adversarial_loss: 0.1408 - val_loss: 0.4006 - val_sparse_categorical_crossentropy: 0.2457 - val_sparse_categorical_accuracy: 0.8959 - val_scaled_adversarial_loss: 0.1548
# Epoch 33/1000
# 11/11 [==============================] - 4s 335ms/step - loss: 0.3989 - sparse_categorical_crossentropy: 0.2512 - sparse_categorical_accuracy: 0.9041 - scaled_adversarial_loss: 0.1477 - val_loss: 0.4051 - val_sparse_categorical_crossentropy: 0.2626 - val_sparse_categorical_accuracy: 0.9026 - val_scaled_adversarial_loss: 0.1425
# Epoch 34/1000
# 11/11 [==============================] - 4s 327ms/step - loss: 0.3952 - sparse_categorical_crossentropy: 0.2528 - sparse_categorical_accuracy: 0.9018 - scaled_adversarial_loss: 0.1424 - val_loss: 0.4020 - val_sparse_categorical_crossentropy: 0.2524 - val_sparse_categorical_accuracy: 0.8981 - val_scaled_adversarial_loss: 0.1496
# Epoch 35/1000
# 11/11 [==============================] - 4s 333ms/step - loss: 0.4029 - sparse_categorical_crossentropy: 0.2560 - sparse_categorical_accuracy: 0.9067 - scaled_adversarial_loss: 0.1468 - val_loss: 0.4046 - val_sparse_categorical_crossentropy: 0.2363 - val_sparse_categorical_accuracy: 0.8974 - val_scaled_adversarial_loss: 0.1684
# Epoch 36/1000
# 11/11 [==============================] - 4s 333ms/step - loss: 0.3902 - sparse_categorical_crossentropy: 0.2418 - sparse_categorical_accuracy: 0.9096 - scaled_adversarial_loss: 0.1484 - val_loss: 0.4002 - val_sparse_categorical_crossentropy: 0.2242 - val_sparse_categorical_accuracy: 0.9056 - val_scaled_adversarial_loss: 0.1760
# Epoch 37/1000
# 11/11 [==============================] - 4s 367ms/step - loss: 0.3919 - sparse_categorical_crossentropy: 0.2450 - sparse_categorical_accuracy: 0.9041 - scaled_adversarial_loss: 0.1469 - val_loss: 0.4023 - val_sparse_categorical_crossentropy: 0.2358 - val_sparse_categorical_accuracy: 0.9138 - val_scaled_adversarial_loss: 0.1665
# Epoch 38/1000
# 11/11 [==============================] - 4s 401ms/step - loss: 0.3976 - sparse_categorical_crossentropy: 0.2532 - sparse_categorical_accuracy: 0.9011 - scaled_adversarial_loss: 0.1445 - val_loss: 0.3960 - val_sparse_categorical_crossentropy: 0.2289 - val_sparse_categorical_accuracy: 0.9115 - val_scaled_adversarial_loss: 0.1672
# Epoch 39/1000
# 11/11 [==============================] - 4s 372ms/step - loss: 0.3977 - sparse_categorical_crossentropy: 0.2494 - sparse_categorical_accuracy: 0.9013 - scaled_adversarial_loss: 0.1484 - val_loss: 0.4081 - val_sparse_categorical_crossentropy: 0.2519 - val_sparse_categorical_accuracy: 0.8892 - val_scaled_adversarial_loss: 0.1561
# Epoch 40/1000
# 11/11 [==============================] - 4s 363ms/step - loss: 0.3981 - sparse_categorical_crossentropy: 0.2507 - sparse_categorical_accuracy: 0.9057 - scaled_adversarial_loss: 0.1474 - val_loss: 0.4018 - val_sparse_categorical_crossentropy: 0.2553 - val_sparse_categorical_accuracy: 0.8996 - val_scaled_adversarial_loss: 0.1465
# Epoch 41/1000
# 11/11 [==============================] - 4s 356ms/step - loss: 0.4015 - sparse_categorical_crossentropy: 0.2563 - sparse_categorical_accuracy: 0.9044 - scaled_adversarial_loss: 0.1452 - val_loss: 0.4023 - val_sparse_categorical_crossentropy: 0.2483 - val_sparse_categorical_accuracy: 0.8952 - val_scaled_adversarial_loss: 0.1540
# Epoch 42/1000
# 11/11 [==============================] - 4s 351ms/step - loss: 0.3935 - sparse_categorical_crossentropy: 0.2467 - sparse_categorical_accuracy: 0.9063 - scaled_adversarial_loss: 0.1468 - val_loss: 0.3936 - val_sparse_categorical_crossentropy: 0.2364 - val_sparse_categorical_accuracy: 0.9041 - val_scaled_adversarial_loss: 0.1572
# Epoch 43/1000
# 11/11 [==============================] - 4s 343ms/step - loss: 0.3908 - sparse_categorical_crossentropy: 0.2457 - sparse_categorical_accuracy: 0.9065 - scaled_adversarial_loss: 0.1451 - val_loss: 0.3940 - val_sparse_categorical_crossentropy: 0.2241 - val_sparse_categorical_accuracy: 0.9086 - val_scaled_adversarial_loss: 0.1699
# Epoch 44/1000
# 11/11 [==============================] - 4s 344ms/step - loss: 0.3953 - sparse_categorical_crossentropy: 0.2484 - sparse_categorical_accuracy: 0.9042 - scaled_adversarial_loss: 0.1469 - val_loss: 0.3936 - val_sparse_categorical_crossentropy: 0.2313 - val_sparse_categorical_accuracy: 0.9048 - val_scaled_adversarial_loss: 0.1623
# Epoch 45/1000
# 11/11 [==============================] - 4s 342ms/step - loss: 0.3908 - sparse_categorical_crossentropy: 0.2458 - sparse_categorical_accuracy: 0.9081 - scaled_adversarial_loss: 0.1451 - val_loss: 0.3971 - val_sparse_categorical_crossentropy: 0.2380 - val_sparse_categorical_accuracy: 0.9004 - val_scaled_adversarial_loss: 0.1590
# Epoch 46/1000
# 11/11 [==============================] - 4s 357ms/step - loss: 0.3947 - sparse_categorical_crossentropy: 0.2477 - sparse_categorical_accuracy: 0.9080 - scaled_adversarial_loss: 0.1470 - val_loss: 0.4054 - val_sparse_categorical_crossentropy: 0.2269 - val_sparse_categorical_accuracy: 0.9056 - val_scaled_adversarial_loss: 0.1785
# Epoch 47/1000
# 11/11 [==============================] - 4s 358ms/step - loss: 0.3954 - sparse_categorical_crossentropy: 0.2464 - sparse_categorical_accuracy: 0.9035 - scaled_adversarial_loss: 0.1490 - val_loss: 0.4027 - val_sparse_categorical_crossentropy: 0.2501 - val_sparse_categorical_accuracy: 0.8959 - val_scaled_adversarial_loss: 0.1526
# Epoch 48/1000
# 11/11 [==============================] - 4s 339ms/step - loss: 0.3969 - sparse_categorical_crossentropy: 0.2503 - sparse_categorical_accuracy: 0.9070 - scaled_adversarial_loss: 0.1466 - val_loss: 0.3958 - val_sparse_categorical_crossentropy: 0.2285 - val_sparse_categorical_accuracy: 0.9048 - val_scaled_adversarial_loss: 0.1673
# Epoch 49/1000
# 11/11 [==============================] - 4s 356ms/step - loss: 0.3959 - sparse_categorical_crossentropy: 0.2475 - sparse_categorical_accuracy: 0.9059 - scaled_adversarial_loss: 0.1484 - val_loss: 0.3936 - val_sparse_categorical_crossentropy: 0.2396 - val_sparse_categorical_accuracy: 0.9123 - val_scaled_adversarial_loss: 0.1540
# Epoch 50/1000
# 11/11 [==============================] - 4s 382ms/step - loss: 0.3936 - sparse_categorical_crossentropy: 0.2455 - sparse_categorical_accuracy: 0.9065 - scaled_adversarial_loss: 0.1481 - val_loss: 0.3931 - val_sparse_categorical_crossentropy: 0.2401 - val_sparse_categorical_accuracy: 0.9086 - val_scaled_adversarial_loss: 0.1530
# Epoch 51/1000
# 11/11 [==============================] - 4s 352ms/step - loss: 0.3953 - sparse_categorical_crossentropy: 0.2498 - sparse_categorical_accuracy: 0.9093 - scaled_adversarial_loss: 0.1455 - val_loss: 0.3988 - val_sparse_categorical_crossentropy: 0.2349 - val_sparse_categorical_accuracy: 0.9011 - val_scaled_adversarial_loss: 0.1640
# Epoch 52/1000
# 11/11 [==============================] - 4s 368ms/step - loss: 0.3932 - sparse_categorical_crossentropy: 0.2438 - sparse_categorical_accuracy: 0.9081 - scaled_adversarial_loss: 0.1493 - val_loss: 0.4130 - val_sparse_categorical_crossentropy: 0.2253 - val_sparse_categorical_accuracy: 0.9033 - val_scaled_adversarial_loss: 0.1877
# Epoch 53/1000
# 11/11 [==============================] - 4s 354ms/step - loss: 0.3987 - sparse_categorical_crossentropy: 0.2467 - sparse_categorical_accuracy: 0.9091 - scaled_adversarial_loss: 0.1520 - val_loss: 0.3906 - val_sparse_categorical_crossentropy: 0.2309 - val_sparse_categorical_accuracy: 0.9063 - val_scaled_adversarial_loss: 0.1597
# Epoch 54/1000
# 11/11 [==============================] - 4s 358ms/step - loss: 0.3903 - sparse_categorical_crossentropy: 0.2428 - sparse_categorical_accuracy: 0.9091 - scaled_adversarial_loss: 0.1475 - val_loss: 0.3978 - val_sparse_categorical_crossentropy: 0.2496 - val_sparse_categorical_accuracy: 0.9086 - val_scaled_adversarial_loss: 0.1482
# Epoch 55/1000
# 11/11 [==============================] - 4s 368ms/step - loss: 0.3891 - sparse_categorical_crossentropy: 0.2436 - sparse_categorical_accuracy: 0.9089 - scaled_adversarial_loss: 0.1455 - val_loss: 0.3947 - val_sparse_categorical_crossentropy: 0.2240 - val_sparse_categorical_accuracy: 0.9063 - val_scaled_adversarial_loss: 0.1707
# Epoch 56/1000
# 11/11 [==============================] - 4s 367ms/step - loss: 0.3924 - sparse_categorical_crossentropy: 0.2419 - sparse_categorical_accuracy: 0.9094 - scaled_adversarial_loss: 0.1505 - val_loss: 0.3904 - val_sparse_categorical_crossentropy: 0.2307 - val_sparse_categorical_accuracy: 0.9138 - val_scaled_adversarial_loss: 0.1597
# Epoch 57/1000
# 11/11 [==============================] - 4s 346ms/step - loss: 0.3924 - sparse_categorical_crossentropy: 0.2459 - sparse_categorical_accuracy: 0.9089 - scaled_adversarial_loss: 0.1465 - val_loss: 0.4006 - val_sparse_categorical_crossentropy: 0.2528 - val_sparse_categorical_accuracy: 0.8989 - val_scaled_adversarial_loss: 0.1478
# Epoch 58/1000
# 11/11 [==============================] - 4s 345ms/step - loss: 0.3941 - sparse_categorical_crossentropy: 0.2494 - sparse_categorical_accuracy: 0.9089 - scaled_adversarial_loss: 0.1447 - val_loss: 0.4007 - val_sparse_categorical_crossentropy: 0.2336 - val_sparse_categorical_accuracy: 0.8996 - val_scaled_adversarial_loss: 0.1671
# Epoch 59/1000
# 11/11 [==============================] - 4s 339ms/step - loss: 0.3871 - sparse_categorical_crossentropy: 0.2411 - sparse_categorical_accuracy: 0.9098 - scaled_adversarial_loss: 0.1460 - val_loss: 0.4021 - val_sparse_categorical_crossentropy: 0.2310 - val_sparse_categorical_accuracy: 0.8989 - val_scaled_adversarial_loss: 0.1711
# Epoch 60/1000
# 11/11 [==============================] - 4s 339ms/step - loss: 0.3962 - sparse_categorical_crossentropy: 0.2469 - sparse_categorical_accuracy: 0.9074 - scaled_adversarial_loss: 0.1493 - val_loss: 0.3932 - val_sparse_categorical_crossentropy: 0.2310 - val_sparse_categorical_accuracy: 0.9041 - val_scaled_adversarial_loss: 0.1622
# Epoch 61/1000
# 11/11 [==============================] - 4s 339ms/step - loss: 0.3929 - sparse_categorical_crossentropy: 0.2442 - sparse_categorical_accuracy: 0.9098 - scaled_adversarial_loss: 0.1487 - val_loss: 0.3915 - val_sparse_categorical_crossentropy: 0.2330 - val_sparse_categorical_accuracy: 0.9071 - val_scaled_adversarial_loss: 0.1585
# Epoch 62/1000
# 11/11 [==============================] - 4s 360ms/step - loss: 0.3858 - sparse_categorical_crossentropy: 0.2398 - sparse_categorical_accuracy: 0.9106 - scaled_adversarial_loss: 0.1460 - val_loss: 0.3933 - val_sparse_categorical_crossentropy: 0.2279 - val_sparse_categorical_accuracy: 0.9063 - val_scaled_adversarial_loss: 0.1654
# Epoch 63/1000
# 11/11 [==============================] - 4s 359ms/step - loss: 0.3933 - sparse_categorical_crossentropy: 0.2408 - sparse_categorical_accuracy: 0.9120 - scaled_adversarial_loss: 0.1525 - val_loss: 0.3942 - val_sparse_categorical_crossentropy: 0.2409 - val_sparse_categorical_accuracy: 0.9071 - val_scaled_adversarial_loss: 0.1534
# Epoch 64/1000
# 11/11 [==============================] - 4s 358ms/step - loss: 0.3944 - sparse_categorical_crossentropy: 0.2483 - sparse_categorical_accuracy: 0.9102 - scaled_adversarial_loss: 0.1462 - val_loss: 0.3961 - val_sparse_categorical_crossentropy: 0.2480 - val_sparse_categorical_accuracy: 0.9048 - val_scaled_adversarial_loss: 0.1482
# Epoch 65/1000
# 11/11 [==============================] - 4s 394ms/step - loss: 0.3864 - sparse_categorical_crossentropy: 0.2408 - sparse_categorical_accuracy: 0.9096 - scaled_adversarial_loss: 0.1456 - val_loss: 0.3913 - val_sparse_categorical_crossentropy: 0.2364 - val_sparse_categorical_accuracy: 0.9093 - val_scaled_adversarial_loss: 0.1549
# Epoch 66/1000
# 11/11 [==============================] - 4s 363ms/step - loss: 0.3924 - sparse_categorical_crossentropy: 0.2443 - sparse_categorical_accuracy: 0.9080 - scaled_adversarial_loss: 0.1481 - val_loss: 0.3987 - val_sparse_categorical_crossentropy: 0.2484 - val_sparse_categorical_accuracy: 0.8981 - val_scaled_adversarial_loss: 0.1503
# Epoch 67/1000
# 11/11 [==============================] - 4s 377ms/step - loss: 0.3930 - sparse_categorical_crossentropy: 0.2457 - sparse_categorical_accuracy: 0.9087 - scaled_adversarial_loss: 0.1473 - val_loss: 0.4010 - val_sparse_categorical_crossentropy: 0.2533 - val_sparse_categorical_accuracy: 0.8996 - val_scaled_adversarial_loss: 0.1476
# Epoch 68/1000
# 11/11 [==============================] - 4s 362ms/step - loss: 0.3948 - sparse_categorical_crossentropy: 0.2491 - sparse_categorical_accuracy: 0.9067 - scaled_adversarial_loss: 0.1457 - val_loss: 0.3949 - val_sparse_categorical_crossentropy: 0.2333 - val_sparse_categorical_accuracy: 0.9056 - val_scaled_adversarial_loss: 0.1616
# Epoch 69/1000
# 11/11 [==============================] - 4s 343ms/step - loss: 0.3918 - sparse_categorical_crossentropy: 0.2407 - sparse_categorical_accuracy: 0.9115 - scaled_adversarial_loss: 0.1511 - val_loss: 0.3931 - val_sparse_categorical_crossentropy: 0.2288 - val_sparse_categorical_accuracy: 0.9093 - val_scaled_adversarial_loss: 0.1644
# Epoch 70/1000
# 11/11 [==============================] - 4s 334ms/step - loss: 0.3916 - sparse_categorical_crossentropy: 0.2439 - sparse_categorical_accuracy: 0.9107 - scaled_adversarial_loss: 0.1477 - val_loss: 0.3954 - val_sparse_categorical_crossentropy: 0.2411 - val_sparse_categorical_accuracy: 0.9004 - val_scaled_adversarial_loss: 0.1543
# Epoch 71/1000
# 11/11 [==============================] - 4s 336ms/step - loss: 0.3888 - sparse_categorical_crossentropy: 0.2406 - sparse_categorical_accuracy: 0.9076 - scaled_adversarial_loss: 0.1482 - val_loss: 0.3964 - val_sparse_categorical_crossentropy: 0.2236 - val_sparse_categorical_accuracy: 0.9071 - val_scaled_adversarial_loss: 0.1728
# Epoch 72/1000
# 11/11 [==============================] - 4s 334ms/step - loss: 0.3946 - sparse_categorical_crossentropy: 0.2418 - sparse_categorical_accuracy: 0.9094 - scaled_adversarial_loss: 0.1528 - val_loss: 0.3900 - val_sparse_categorical_crossentropy: 0.2277 - val_sparse_categorical_accuracy: 0.9086 - val_scaled_adversarial_loss: 0.1623
# Epoch 73/1000
# 11/11 [==============================] - 4s 337ms/step - loss: 0.3948 - sparse_categorical_crossentropy: 0.2431 - sparse_categorical_accuracy: 0.9100 - scaled_adversarial_loss: 0.1517 - val_loss: 0.4076 - val_sparse_categorical_crossentropy: 0.2629 - val_sparse_categorical_accuracy: 0.8952 - val_scaled_adversarial_loss: 0.1447
# Epoch 74/1000
# 11/11 [==============================] - 4s 345ms/step - loss: 0.3927 - sparse_categorical_crossentropy: 0.2473 - sparse_categorical_accuracy: 0.9078 - scaled_adversarial_loss: 0.1454 - val_loss: 0.3914 - val_sparse_categorical_crossentropy: 0.2311 - val_sparse_categorical_accuracy: 0.9063 - val_scaled_adversarial_loss: 0.1603
# Epoch 75/1000
# 11/11 [==============================] - 4s 345ms/step - loss: 0.3893 - sparse_categorical_crossentropy: 0.2402 - sparse_categorical_accuracy: 0.9087 - scaled_adversarial_loss: 0.1491 - val_loss: 0.3923 - val_sparse_categorical_crossentropy: 0.2237 - val_sparse_categorical_accuracy: 0.9086 - val_scaled_adversarial_loss: 0.1686
# Epoch 76/1000
# 11/11 [==============================] - 4s 338ms/step - loss: 0.3897 - sparse_categorical_crossentropy: 0.2398 - sparse_categorical_accuracy: 0.9093 - scaled_adversarial_loss: 0.1499 - val_loss: 0.3938 - val_sparse_categorical_crossentropy: 0.2320 - val_sparse_categorical_accuracy: 0.9033 - val_scaled_adversarial_loss: 0.1618
# Epoch 77/1000
# 11/11 [==============================] - 4s 350ms/step - loss: 0.3947 - sparse_categorical_crossentropy: 0.2451 - sparse_categorical_accuracy: 0.9100 - scaled_adversarial_loss: 0.1496 - val_loss: 0.4153 - val_sparse_categorical_crossentropy: 0.2739 - val_sparse_categorical_accuracy: 0.8892 - val_scaled_adversarial_loss: 0.1414
# Epoch 78/1000
# 11/11 [==============================] - 4s 359ms/step - loss: 0.3908 - sparse_categorical_crossentropy: 0.2432 - sparse_categorical_accuracy: 0.9120 - scaled_adversarial_loss: 0.1477 - val_loss: 0.3973 - val_sparse_categorical_crossentropy: 0.2463 - val_sparse_categorical_accuracy: 0.8989 - val_scaled_adversarial_loss: 0.1510
# Epoch 79/1000
# 11/11 [==============================] - 4s 363ms/step - loss: 0.3887 - sparse_categorical_crossentropy: 0.2402 - sparse_categorical_accuracy: 0.9120 - scaled_adversarial_loss: 0.1486 - val_loss: 0.3905 - val_sparse_categorical_crossentropy: 0.2320 - val_sparse_categorical_accuracy: 0.9086 - val_scaled_adversarial_loss: 0.1585
# Epoch 80/1000
# 11/11 [==============================] - 4s 374ms/step - loss: 0.3920 - sparse_categorical_crossentropy: 0.2413 - sparse_categorical_accuracy: 0.9104 - scaled_adversarial_loss: 0.1507 - val_loss: 0.3917 - val_sparse_categorical_crossentropy: 0.2361 - val_sparse_categorical_accuracy: 0.9078 - val_scaled_adversarial_loss: 0.1556
# Epoch 81/1000
# 11/11 [==============================] - 4s 363ms/step - loss: 0.3919 - sparse_categorical_crossentropy: 0.2444 - sparse_categorical_accuracy: 0.9089 - scaled_adversarial_loss: 0.1474 - val_loss: 0.3919 - val_sparse_categorical_crossentropy: 0.2386 - val_sparse_categorical_accuracy: 0.9063 - val_scaled_adversarial_loss: 0.1533
# Epoch 82/1000
# 11/11 [==============================] - 4s 377ms/step - loss: 0.3915 - sparse_categorical_crossentropy: 0.2411 - sparse_categorical_accuracy: 0.9117 - scaled_adversarial_loss: 0.1504 - val_loss: 0.3920 - val_sparse_categorical_crossentropy: 0.2331 - val_sparse_categorical_accuracy: 0.9071 - val_scaled_adversarial_loss: 0.1589
# Epoch 83/1000
# 11/11 [==============================] - 4s 364ms/step - loss: 0.3899 - sparse_categorical_crossentropy: 0.2419 - sparse_categorical_accuracy: 0.9107 - scaled_adversarial_loss: 0.1480 - val_loss: 0.3940 - val_sparse_categorical_crossentropy: 0.2430 - val_sparse_categorical_accuracy: 0.9078 - val_scaled_adversarial_loss: 0.1510
# Epoch 84/1000
# 11/11 [==============================] - 4s 351ms/step - loss: 0.3864 - sparse_categorical_crossentropy: 0.2381 - sparse_categorical_accuracy: 0.9102 - scaled_adversarial_loss: 0.1484 - val_loss: 0.3922 - val_sparse_categorical_crossentropy: 0.2315 - val_sparse_categorical_accuracy: 0.9056 - val_scaled_adversarial_loss: 0.1607
# Epoch 85/1000
# 11/11 [==============================] - 4s 356ms/step - loss: 0.3916 - sparse_categorical_crossentropy: 0.2387 - sparse_categorical_accuracy: 0.9106 - scaled_adversarial_loss: 0.1528 - val_loss: 0.3967 - val_sparse_categorical_crossentropy: 0.2235 - val_sparse_categorical_accuracy: 0.9078 - val_scaled_adversarial_loss: 0.1732
# Epoch 86/1000
# 11/11 [==============================] - 4s 363ms/step - loss: 0.3877 - sparse_categorical_crossentropy: 0.2413 - sparse_categorical_accuracy: 0.9078 - scaled_adversarial_loss: 0.1464 - val_loss: 0.3915 - val_sparse_categorical_crossentropy: 0.2338 - val_sparse_categorical_accuracy: 0.9078 - val_scaled_adversarial_loss: 0.1577
# Epoch 87/1000
# 11/11 [==============================] - 4s 357ms/step - loss: 0.3902 - sparse_categorical_crossentropy: 0.2423 - sparse_categorical_accuracy: 0.9083 - scaled_adversarial_loss: 0.1479 - val_loss: 0.3952 - val_sparse_categorical_crossentropy: 0.2283 - val_sparse_categorical_accuracy: 0.9130 - val_scaled_adversarial_loss: 0.1669
# Epoch 88/1000
# 11/11 [==============================] - 4s 362ms/step - loss: 0.3892 - sparse_categorical_crossentropy: 0.2398 - sparse_categorical_accuracy: 0.9089 - scaled_adversarial_loss: 0.1493 - val_loss: 0.3925 - val_sparse_categorical_crossentropy: 0.2295 - val_sparse_categorical_accuracy: 0.9130 - val_scaled_adversarial_loss: 0.1630
# Epoch 89/1000
# 11/11 [==============================] - 4s 358ms/step - loss: 0.3933 - sparse_categorical_crossentropy: 0.2447 - sparse_categorical_accuracy: 0.9115 - scaled_adversarial_loss: 0.1486 - val_loss: 0.3892 - val_sparse_categorical_crossentropy: 0.2261 - val_sparse_categorical_accuracy: 0.9152 - val_scaled_adversarial_loss: 0.1631
# Epoch 90/1000
# 11/11 [==============================] - 4s 351ms/step - loss: 0.3833 - sparse_categorical_crossentropy: 0.2360 - sparse_categorical_accuracy: 0.9124 - scaled_adversarial_loss: 0.1473 - val_loss: 0.3959 - val_sparse_categorical_crossentropy: 0.2450 - val_sparse_categorical_accuracy: 0.9086 - val_scaled_adversarial_loss: 0.1509
# Epoch 91/1000
# 11/11 [==============================] - 4s 356ms/step - loss: 0.3837 - sparse_categorical_crossentropy: 0.2371 - sparse_categorical_accuracy: 0.9109 - scaled_adversarial_loss: 0.1466 - val_loss: 0.3893 - val_sparse_categorical_crossentropy: 0.2280 - val_sparse_categorical_accuracy: 0.9115 - val_scaled_adversarial_loss: 0.1612
# Epoch 92/1000
# 11/11 [==============================] - 4s 356ms/step - loss: 0.3865 - sparse_categorical_crossentropy: 0.2363 - sparse_categorical_accuracy: 0.9126 - scaled_adversarial_loss: 0.1502 - val_loss: 0.3908 - val_sparse_categorical_crossentropy: 0.2311 - val_sparse_categorical_accuracy: 0.9086 - val_scaled_adversarial_loss: 0.1597
# Epoch 93/1000
# 11/11 [==============================] - 4s 356ms/step - loss: 0.3903 - sparse_categorical_crossentropy: 0.2429 - sparse_categorical_accuracy: 0.9102 - scaled_adversarial_loss: 0.1475 - val_loss: 0.3958 - val_sparse_categorical_crossentropy: 0.2473 - val_sparse_categorical_accuracy: 0.9086 - val_scaled_adversarial_loss: 0.1485
# Epoch 94/1000
# 11/11 [==============================] - 4s 346ms/step - loss: 0.3844 - sparse_categorical_crossentropy: 0.2373 - sparse_categorical_accuracy: 0.9120 - scaled_adversarial_loss: 0.1471 - val_loss: 0.3901 - val_sparse_categorical_crossentropy: 0.2332 - val_sparse_categorical_accuracy: 0.9100 - val_scaled_adversarial_loss: 0.1569
# Epoch 95/1000
# 11/11 [==============================] - 4s 342ms/step - loss: 0.3850 - sparse_categorical_crossentropy: 0.2395 - sparse_categorical_accuracy: 0.9115 - scaled_adversarial_loss: 0.1455 - val_loss: 0.3938 - val_sparse_categorical_crossentropy: 0.2314 - val_sparse_categorical_accuracy: 0.9078 - val_scaled_adversarial_loss: 0.1625
# Epoch 96/1000
# 11/11 [==============================] - 4s 344ms/step - loss: 0.3816 - sparse_categorical_crossentropy: 0.2339 - sparse_categorical_accuracy: 0.9104 - scaled_adversarial_loss: 0.1477 - val_loss: 0.3934 - val_sparse_categorical_crossentropy: 0.2366 - val_sparse_categorical_accuracy: 0.9078 - val_scaled_adversarial_loss: 0.1568
# Epoch 97/1000
# 11/11 [==============================] - 4s 340ms/step - loss: 0.3833 - sparse_categorical_crossentropy: 0.2367 - sparse_categorical_accuracy: 0.9106 - scaled_adversarial_loss: 0.1465 - val_loss: 0.3966 - val_sparse_categorical_crossentropy: 0.2288 - val_sparse_categorical_accuracy: 0.9056 - val_scaled_adversarial_loss: 0.1678
# Epoch 98/1000
# 11/11 [==============================] - 4s 342ms/step - loss: 0.3904 - sparse_categorical_crossentropy: 0.2410 - sparse_categorical_accuracy: 0.9078 - scaled_adversarial_loss: 0.1494 - val_loss: 0.3934 - val_sparse_categorical_crossentropy: 0.2306 - val_sparse_categorical_accuracy: 0.9078 - val_scaled_adversarial_loss: 0.1628
# Epoch 99/1000
# 11/11 [==============================] - 4s 344ms/step - loss: 0.3845 - sparse_categorical_crossentropy: 0.2373 - sparse_categorical_accuracy: 0.9135 - scaled_adversarial_loss: 0.1472 - val_loss: 0.3964 - val_sparse_categorical_crossentropy: 0.2443 - val_sparse_categorical_accuracy: 0.9011 - val_scaled_adversarial_loss: 0.1521
# Epoch 100/1000
# 11/11 [==============================] - 4s 344ms/step - loss: 0.3818 - sparse_categorical_crossentropy: 0.2358 - sparse_categorical_accuracy: 0.9111 - scaled_adversarial_loss: 0.1460 - val_loss: 0.3923 - val_sparse_categorical_crossentropy: 0.2226 - val_sparse_categorical_accuracy: 0.9086 - val_scaled_adversarial_loss: 0.1698
# Epoch 101/1000
# 11/11 [==============================] - 4s 342ms/step - loss: 0.3829 - sparse_categorical_crossentropy: 0.2343 - sparse_categorical_accuracy: 0.9117 - scaled_adversarial_loss: 0.1485 - val_loss: 0.3886 - val_sparse_categorical_crossentropy: 0.2247 - val_sparse_categorical_accuracy: 0.9152 - val_scaled_adversarial_loss: 0.1638
# Epoch 102/1000
# 11/11 [==============================] - 4s 346ms/step - loss: 0.3832 - sparse_categorical_crossentropy: 0.2362 - sparse_categorical_accuracy: 0.9134 - scaled_adversarial_loss: 0.1470 - val_loss: 0.3884 - val_sparse_categorical_crossentropy: 0.2302 - val_sparse_categorical_accuracy: 0.9108 - val_scaled_adversarial_loss: 0.1582
# Epoch 103/1000
# 11/11 [==============================] - 4s 344ms/step - loss: 0.3810 - sparse_categorical_crossentropy: 0.2350 - sparse_categorical_accuracy: 0.9100 - scaled_adversarial_loss: 0.1460 - val_loss: 0.3950 - val_sparse_categorical_crossentropy: 0.2210 - val_sparse_categorical_accuracy: 0.9071 - val_scaled_adversarial_loss: 0.1740
# Epoch 104/1000
# 11/11 [==============================] - 4s 342ms/step - loss: 0.3880 - sparse_categorical_crossentropy: 0.2372 - sparse_categorical_accuracy: 0.9113 - scaled_adversarial_loss: 0.1508 - val_loss: 0.3919 - val_sparse_categorical_crossentropy: 0.2445 - val_sparse_categorical_accuracy: 0.9138 - val_scaled_adversarial_loss: 0.1474
# Epoch 105/1000
# 11/11 [==============================] - 4s 343ms/step - loss: 0.3825 - sparse_categorical_crossentropy: 0.2383 - sparse_categorical_accuracy: 0.9096 - scaled_adversarial_loss: 0.1442 - val_loss: 0.3865 - val_sparse_categorical_crossentropy: 0.2246 - val_sparse_categorical_accuracy: 0.9093 - val_scaled_adversarial_loss: 0.1619
# Epoch 106/1000
# 11/11 [==============================] - 4s 346ms/step - loss: 0.3744 - sparse_categorical_crossentropy: 0.2290 - sparse_categorical_accuracy: 0.9134 - scaled_adversarial_loss: 0.1454 - val_loss: 0.3867 - val_sparse_categorical_crossentropy: 0.2220 - val_sparse_categorical_accuracy: 0.9175 - val_scaled_adversarial_loss: 0.1647
# Epoch 107/1000
# 11/11 [==============================] - 4s 347ms/step - loss: 0.3807 - sparse_categorical_crossentropy: 0.2353 - sparse_categorical_accuracy: 0.9109 - scaled_adversarial_loss: 0.1454 - val_loss: 0.3849 - val_sparse_categorical_crossentropy: 0.2315 - val_sparse_categorical_accuracy: 0.9108 - val_scaled_adversarial_loss: 0.1533
# Epoch 108/1000
# 11/11 [==============================] - 4s 341ms/step - loss: 0.3763 - sparse_categorical_crossentropy: 0.2311 - sparse_categorical_accuracy: 0.9143 - scaled_adversarial_loss: 0.1453 - val_loss: 0.3887 - val_sparse_categorical_crossentropy: 0.2354 - val_sparse_categorical_accuracy: 0.9033 - val_scaled_adversarial_loss: 0.1533
# Epoch 109/1000
# 11/11 [==============================] - 4s 371ms/step - loss: 0.3826 - sparse_categorical_crossentropy: 0.2366 - sparse_categorical_accuracy: 0.9120 - scaled_adversarial_loss: 0.1460 - val_loss: 0.3907 - val_sparse_categorical_crossentropy: 0.2383 - val_sparse_categorical_accuracy: 0.9004 - val_scaled_adversarial_loss: 0.1524
# Epoch 110/1000
# 11/11 [==============================] - 4s 371ms/step - loss: 0.3803 - sparse_categorical_crossentropy: 0.2362 - sparse_categorical_accuracy: 0.9100 - scaled_adversarial_loss: 0.1441 - val_loss: 0.3811 - val_sparse_categorical_crossentropy: 0.2264 - val_sparse_categorical_accuracy: 0.9130 - val_scaled_adversarial_loss: 0.1547
# Epoch 111/1000
# 11/11 [==============================] - 4s 368ms/step - loss: 0.3704 - sparse_categorical_crossentropy: 0.2255 - sparse_categorical_accuracy: 0.9154 - scaled_adversarial_loss: 0.1450 - val_loss: 0.3872 - val_sparse_categorical_crossentropy: 0.2259 - val_sparse_categorical_accuracy: 0.9063 - val_scaled_adversarial_loss: 0.1613
# Epoch 112/1000
# 11/11 [==============================] - 4s 365ms/step - loss: 0.3720 - sparse_categorical_crossentropy: 0.2264 - sparse_categorical_accuracy: 0.9152 - scaled_adversarial_loss: 0.1457 - val_loss: 0.3905 - val_sparse_categorical_crossentropy: 0.2354 - val_sparse_categorical_accuracy: 0.9033 - val_scaled_adversarial_loss: 0.1552
# Epoch 113/1000
# 11/11 [==============================] - 4s 369ms/step - loss: 0.3714 - sparse_categorical_crossentropy: 0.2293 - sparse_categorical_accuracy: 0.9135 - scaled_adversarial_loss: 0.1421 - val_loss: 0.3822 - val_sparse_categorical_crossentropy: 0.2295 - val_sparse_categorical_accuracy: 0.9078 - val_scaled_adversarial_loss: 0.1527
# Epoch 114/1000
# 11/11 [==============================] - 4s 370ms/step - loss: 0.3721 - sparse_categorical_crossentropy: 0.2296 - sparse_categorical_accuracy: 0.9130 - scaled_adversarial_loss: 0.1425 - val_loss: 0.3806 - val_sparse_categorical_crossentropy: 0.2068 - val_sparse_categorical_accuracy: 0.9167 - val_scaled_adversarial_loss: 0.1739
# Epoch 115/1000
# 11/11 [==============================] - 4s 375ms/step - loss: 0.3682 - sparse_categorical_crossentropy: 0.2263 - sparse_categorical_accuracy: 0.9182 - scaled_adversarial_loss: 0.1419 - val_loss: 0.3741 - val_sparse_categorical_crossentropy: 0.2216 - val_sparse_categorical_accuracy: 0.9152 - val_scaled_adversarial_loss: 0.1526
# Epoch 116/1000
# 11/11 [==============================] - 4s 378ms/step - loss: 0.3579 - sparse_categorical_crossentropy: 0.2199 - sparse_categorical_accuracy: 0.9169 - scaled_adversarial_loss: 0.1380 - val_loss: 0.3708 - val_sparse_categorical_crossentropy: 0.2034 - val_sparse_categorical_accuracy: 0.9182 - val_scaled_adversarial_loss: 0.1674
# Epoch 117/1000
# 11/11 [==============================] - 4s 370ms/step - loss: 0.3662 - sparse_categorical_crossentropy: 0.2199 - sparse_categorical_accuracy: 0.9180 - scaled_adversarial_loss: 0.1463 - val_loss: 0.3713 - val_sparse_categorical_crossentropy: 0.2024 - val_sparse_categorical_accuracy: 0.9212 - val_scaled_adversarial_loss: 0.1689
# Epoch 118/1000
# 11/11 [==============================] - 4s 368ms/step - loss: 0.3617 - sparse_categorical_crossentropy: 0.2258 - sparse_categorical_accuracy: 0.9143 - scaled_adversarial_loss: 0.1358 - val_loss: 0.3548 - val_sparse_categorical_crossentropy: 0.2041 - val_sparse_categorical_accuracy: 0.9167 - val_scaled_adversarial_loss: 0.1506
# Epoch 119/1000
# 11/11 [==============================] - 4s 368ms/step - loss: 0.3481 - sparse_categorical_crossentropy: 0.2178 - sparse_categorical_accuracy: 0.9169 - scaled_adversarial_loss: 0.1303 - val_loss: 0.3487 - val_sparse_categorical_crossentropy: 0.2001 - val_sparse_categorical_accuracy: 0.9175 - val_scaled_adversarial_loss: 0.1487
# Epoch 120/1000
# 11/11 [==============================] - 4s 362ms/step - loss: 0.3545 - sparse_categorical_crossentropy: 0.2212 - sparse_categorical_accuracy: 0.9180 - scaled_adversarial_loss: 0.1334 - val_loss: 0.3534 - val_sparse_categorical_crossentropy: 0.2010 - val_sparse_categorical_accuracy: 0.9152 - val_scaled_adversarial_loss: 0.1524
# Epoch 121/1000
# 11/11 [==============================] - 4s 369ms/step - loss: 0.3536 - sparse_categorical_crossentropy: 0.2221 - sparse_categorical_accuracy: 0.9158 - scaled_adversarial_loss: 0.1315 - val_loss: 0.3472 - val_sparse_categorical_crossentropy: 0.2169 - val_sparse_categorical_accuracy: 0.9167 - val_scaled_adversarial_loss: 0.1304
# Epoch 122/1000
# 11/11 [==============================] - 4s 371ms/step - loss: 0.3425 - sparse_categorical_crossentropy: 0.2175 - sparse_categorical_accuracy: 0.9184 - scaled_adversarial_loss: 0.1250 - val_loss: 0.3366 - val_sparse_categorical_crossentropy: 0.2046 - val_sparse_categorical_accuracy: 0.9197 - val_scaled_adversarial_loss: 0.1320
# Epoch 123/1000
# 11/11 [==============================] - 4s 367ms/step - loss: 0.3377 - sparse_categorical_crossentropy: 0.2157 - sparse_categorical_accuracy: 0.9186 - scaled_adversarial_loss: 0.1219 - val_loss: 0.3421 - val_sparse_categorical_crossentropy: 0.2138 - val_sparse_categorical_accuracy: 0.9212 - val_scaled_adversarial_loss: 0.1283
# Epoch 124/1000
# 11/11 [==============================] - 4s 349ms/step - loss: 0.3389 - sparse_categorical_crossentropy: 0.2132 - sparse_categorical_accuracy: 0.9206 - scaled_adversarial_loss: 0.1257 - val_loss: 0.3406 - val_sparse_categorical_crossentropy: 0.1977 - val_sparse_categorical_accuracy: 0.9257 - val_scaled_adversarial_loss: 0.1429
# Epoch 125/1000
# 11/11 [==============================] - 4s 367ms/step - loss: 0.3352 - sparse_categorical_crossentropy: 0.2113 - sparse_categorical_accuracy: 0.9238 - scaled_adversarial_loss: 0.1239 - val_loss: 0.3330 - val_sparse_categorical_crossentropy: 0.1968 - val_sparse_categorical_accuracy: 0.9249 - val_scaled_adversarial_loss: 0.1362
# Epoch 126/1000
# 11/11 [==============================] - 4s 355ms/step - loss: 0.3357 - sparse_categorical_crossentropy: 0.2144 - sparse_categorical_accuracy: 0.9238 - scaled_adversarial_loss: 0.1212 - val_loss: 0.3339 - val_sparse_categorical_crossentropy: 0.1930 - val_sparse_categorical_accuracy: 0.9227 - val_scaled_adversarial_loss: 0.1409
# Epoch 127/1000
# 11/11 [==============================] - 4s 352ms/step - loss: 0.3359 - sparse_categorical_crossentropy: 0.2120 - sparse_categorical_accuracy: 0.9230 - scaled_adversarial_loss: 0.1240 - val_loss: 0.3378 - val_sparse_categorical_crossentropy: 0.1932 - val_sparse_categorical_accuracy: 0.9227 - val_scaled_adversarial_loss: 0.1445
# Epoch 128/1000
# 11/11 [==============================] - 4s 366ms/step - loss: 0.3300 - sparse_categorical_crossentropy: 0.2049 - sparse_categorical_accuracy: 0.9247 - scaled_adversarial_loss: 0.1250 - val_loss: 0.3317 - val_sparse_categorical_crossentropy: 0.2020 - val_sparse_categorical_accuracy: 0.9227 - val_scaled_adversarial_loss: 0.1297
# Epoch 129/1000
# 11/11 [==============================] - 4s 355ms/step - loss: 0.3239 - sparse_categorical_crossentropy: 0.2051 - sparse_categorical_accuracy: 0.9238 - scaled_adversarial_loss: 0.1188 - val_loss: 0.3242 - val_sparse_categorical_crossentropy: 0.1989 - val_sparse_categorical_accuracy: 0.9234 - val_scaled_adversarial_loss: 0.1253
# Epoch 130/1000
# 11/11 [==============================] - 4s 346ms/step - loss: 0.3227 - sparse_categorical_crossentropy: 0.2047 - sparse_categorical_accuracy: 0.9208 - scaled_adversarial_loss: 0.1180 - val_loss: 0.3290 - val_sparse_categorical_crossentropy: 0.1938 - val_sparse_categorical_accuracy: 0.9212 - val_scaled_adversarial_loss: 0.1352
# Epoch 131/1000
# 11/11 [==============================] - 4s 344ms/step - loss: 0.3280 - sparse_categorical_crossentropy: 0.2065 - sparse_categorical_accuracy: 0.9234 - scaled_adversarial_loss: 0.1215 - val_loss: 0.3316 - val_sparse_categorical_crossentropy: 0.1922 - val_sparse_categorical_accuracy: 0.9234 - val_scaled_adversarial_loss: 0.1394
# Epoch 132/1000
# 11/11 [==============================] - 4s 345ms/step - loss: 0.3222 - sparse_categorical_crossentropy: 0.2065 - sparse_categorical_accuracy: 0.9249 - scaled_adversarial_loss: 0.1157 - val_loss: 0.3194 - val_sparse_categorical_crossentropy: 0.1942 - val_sparse_categorical_accuracy: 0.9227 - val_scaled_adversarial_loss: 0.1252
# Epoch 133/1000
# 11/11 [==============================] - 4s 363ms/step - loss: 0.3218 - sparse_categorical_crossentropy: 0.2031 - sparse_categorical_accuracy: 0.9245 - scaled_adversarial_loss: 0.1187 - val_loss: 0.3293 - val_sparse_categorical_crossentropy: 0.1885 - val_sparse_categorical_accuracy: 0.9212 - val_scaled_adversarial_loss: 0.1408
# Epoch 134/1000
# 11/11 [==============================] - 4s 358ms/step - loss: 0.3159 - sparse_categorical_crossentropy: 0.2009 - sparse_categorical_accuracy: 0.9243 - scaled_adversarial_loss: 0.1150 - val_loss: 0.3190 - val_sparse_categorical_crossentropy: 0.1896 - val_sparse_categorical_accuracy: 0.9234 - val_scaled_adversarial_loss: 0.1294
# Epoch 135/1000
# 11/11 [==============================] - 4s 355ms/step - loss: 0.3196 - sparse_categorical_crossentropy: 0.2053 - sparse_categorical_accuracy: 0.9258 - scaled_adversarial_loss: 0.1143 - val_loss: 0.3142 - val_sparse_categorical_crossentropy: 0.1841 - val_sparse_categorical_accuracy: 0.9204 - val_scaled_adversarial_loss: 0.1301
# Epoch 136/1000
# 11/11 [==============================] - 4s 355ms/step - loss: 0.3142 - sparse_categorical_crossentropy: 0.1994 - sparse_categorical_accuracy: 0.9253 - scaled_adversarial_loss: 0.1147 - val_loss: 0.3173 - val_sparse_categorical_crossentropy: 0.1895 - val_sparse_categorical_accuracy: 0.9219 - val_scaled_adversarial_loss: 0.1278
# Epoch 137/1000
# 11/11 [==============================] - 4s 350ms/step - loss: 0.3078 - sparse_categorical_crossentropy: 0.1970 - sparse_categorical_accuracy: 0.9258 - scaled_adversarial_loss: 0.1109 - val_loss: 0.3208 - val_sparse_categorical_crossentropy: 0.2005 - val_sparse_categorical_accuracy: 0.9204 - val_scaled_adversarial_loss: 0.1202
# Epoch 138/1000
# 11/11 [==============================] - 4s 351ms/step - loss: 0.3130 - sparse_categorical_crossentropy: 0.2014 - sparse_categorical_accuracy: 0.9223 - scaled_adversarial_loss: 0.1116 - val_loss: 0.3287 - val_sparse_categorical_crossentropy: 0.2069 - val_sparse_categorical_accuracy: 0.9204 - val_scaled_adversarial_loss: 0.1218
# Epoch 139/1000
# ...
# Epoch 955/1000
# 11/11 [==============================] - 4s 368ms/step - loss: 0.1284 - sparse_categorical_crossentropy: 0.0674 - sparse_categorical_accuracy: 0.9769 - scaled_adversarial_loss: 0.0610 - val_loss: 0.1741 - val_sparse_categorical_crossentropy: 0.1141 - val_sparse_categorical_accuracy: 0.9561 - val_scaled_adversarial_loss: 0.0601
# Epoch 956/1000
# 11/11 [==============================] - 4s 379ms/step - loss: 0.1251 - sparse_categorical_crossentropy: 0.0649 - sparse_categorical_accuracy: 0.9781 - scaled_adversarial_loss: 0.0602 - val_loss: 0.1555 - val_sparse_categorical_crossentropy: 0.0987 - val_sparse_categorical_accuracy: 0.9636 - val_scaled_adversarial_loss: 0.0569
# Epoch 957/1000
# 11/11 [==============================] - 4s 366ms/step - loss: 0.1232 - sparse_categorical_crossentropy: 0.0611 - sparse_categorical_accuracy: 0.9799 - scaled_adversarial_loss: 0.0622 - val_loss: 0.1654 - val_sparse_categorical_crossentropy: 0.1082 - val_sparse_categorical_accuracy: 0.9621 - val_scaled_adversarial_loss: 0.0572
# Epoch 958/1000
# 11/11 [==============================] - 4s 359ms/step - loss: 0.1168 - sparse_categorical_crossentropy: 0.0597 - sparse_categorical_accuracy: 0.9801 - scaled_adversarial_loss: 0.0571 - val_loss: 0.1594 - val_sparse_categorical_crossentropy: 0.1039 - val_sparse_categorical_accuracy: 0.9613 - val_scaled_adversarial_loss: 0.0555
# Epoch 959/1000
# 11/11 [==============================] - 4s 361ms/step - loss: 0.1104 - sparse_categorical_crossentropy: 0.0516 - sparse_categorical_accuracy: 0.9814 - scaled_adversarial_loss: 0.0589 - val_loss: 0.1638 - val_sparse_categorical_crossentropy: 0.1066 - val_sparse_categorical_accuracy: 0.9613 - val_scaled_adversarial_loss: 0.0572
# Epoch 960/1000
# 11/11 [==============================] - 4s 363ms/step - loss: 0.1142 - sparse_categorical_crossentropy: 0.0527 - sparse_categorical_accuracy: 0.9810 - scaled_adversarial_loss: 0.0615 - val_loss: 0.1909 - val_sparse_categorical_crossentropy: 0.1232 - val_sparse_categorical_accuracy: 0.9613 - val_scaled_adversarial_loss: 0.0677
# Epoch 961/1000
# 11/11 [==============================] - 4s 363ms/step - loss: 0.1227 - sparse_categorical_crossentropy: 0.0654 - sparse_categorical_accuracy: 0.9777 - scaled_adversarial_loss: 0.0574 - val_loss: 0.2014 - val_sparse_categorical_crossentropy: 0.1302 - val_sparse_categorical_accuracy: 0.9606 - val_scaled_adversarial_loss: 0.0712
# Epoch 962/1000
# 11/11 [==============================] - 4s 374ms/step - loss: 0.1120 - sparse_categorical_crossentropy: 0.0542 - sparse_categorical_accuracy: 0.9805 - scaled_adversarial_loss: 0.0578 - val_loss: 0.2064 - val_sparse_categorical_crossentropy: 0.1338 - val_sparse_categorical_accuracy: 0.9621 - val_scaled_adversarial_loss: 0.0726
# Epoch 963/1000
# 11/11 [==============================] - 4s 360ms/step - loss: 0.1108 - sparse_categorical_crossentropy: 0.0510 - sparse_categorical_accuracy: 0.9818 - scaled_adversarial_loss: 0.0598 - val_loss: 0.1807 - val_sparse_categorical_crossentropy: 0.1254 - val_sparse_categorical_accuracy: 0.9613 - val_scaled_adversarial_loss: 0.0552
# Epoch 964/1000
# 11/11 [==============================] - 4s 365ms/step - loss: 0.1103 - sparse_categorical_crossentropy: 0.0543 - sparse_categorical_accuracy: 0.9814 - scaled_adversarial_loss: 0.0560 - val_loss: 0.1795 - val_sparse_categorical_crossentropy: 0.1240 - val_sparse_categorical_accuracy: 0.9606 - val_scaled_adversarial_loss: 0.0555
# Epoch 965/1000
# 11/11 [==============================] - 4s 376ms/step - loss: 0.1169 - sparse_categorical_crossentropy: 0.0592 - sparse_categorical_accuracy: 0.9803 - scaled_adversarial_loss: 0.0577 - val_loss: 0.1752 - val_sparse_categorical_crossentropy: 0.1184 - val_sparse_categorical_accuracy: 0.9599 - val_scaled_adversarial_loss: 0.0569
# Epoch 966/1000
# 11/11 [==============================] - 4s 359ms/step - loss: 0.1163 - sparse_categorical_crossentropy: 0.0590 - sparse_categorical_accuracy: 0.9795 - scaled_adversarial_loss: 0.0573 - val_loss: 0.2033 - val_sparse_categorical_crossentropy: 0.1414 - val_sparse_categorical_accuracy: 0.9606 - val_scaled_adversarial_loss: 0.0618
# Epoch 967/1000
# 11/11 [==============================] - 4s 354ms/step - loss: 0.1150 - sparse_categorical_crossentropy: 0.0572 - sparse_categorical_accuracy: 0.9792 - scaled_adversarial_loss: 0.0578 - val_loss: 0.1872 - val_sparse_categorical_crossentropy: 0.1262 - val_sparse_categorical_accuracy: 0.9591 - val_scaled_adversarial_loss: 0.0610
# Epoch 968/1000
# 11/11 [==============================] - 4s 352ms/step - loss: 0.1149 - sparse_categorical_crossentropy: 0.0573 - sparse_categorical_accuracy: 0.9799 - scaled_adversarial_loss: 0.0576 - val_loss: 0.1822 - val_sparse_categorical_crossentropy: 0.1210 - val_sparse_categorical_accuracy: 0.9546 - val_scaled_adversarial_loss: 0.0613
# Epoch 969/1000
# 11/11 [==============================] - 4s 350ms/step - loss: 0.1128 - sparse_categorical_crossentropy: 0.0555 - sparse_categorical_accuracy: 0.9801 - scaled_adversarial_loss: 0.0573 - val_loss: 0.1909 - val_sparse_categorical_crossentropy: 0.1304 - val_sparse_categorical_accuracy: 0.9628 - val_scaled_adversarial_loss: 0.0605
# Epoch 970/1000
# 11/11 [==============================] - 4s 347ms/step - loss: 0.1122 - sparse_categorical_crossentropy: 0.0521 - sparse_categorical_accuracy: 0.9833 - scaled_adversarial_loss: 0.0601 - val_loss: 0.1706 - val_sparse_categorical_crossentropy: 0.1147 - val_sparse_categorical_accuracy: 0.9636 - val_scaled_adversarial_loss: 0.0559
# Epoch 971/1000
# 11/11 [==============================] - 4s 350ms/step - loss: 0.1116 - sparse_categorical_crossentropy: 0.0530 - sparse_categorical_accuracy: 0.9805 - scaled_adversarial_loss: 0.0586 - val_loss: 0.1580 - val_sparse_categorical_crossentropy: 0.1038 - val_sparse_categorical_accuracy: 0.9636 - val_scaled_adversarial_loss: 0.0542
# Epoch 972/1000
# 11/11 [==============================] - 4s 358ms/step - loss: 0.1133 - sparse_categorical_crossentropy: 0.0560 - sparse_categorical_accuracy: 0.9807 - scaled_adversarial_loss: 0.0573 - val_loss: 0.1598 - val_sparse_categorical_crossentropy: 0.1039 - val_sparse_categorical_accuracy: 0.9591 - val_scaled_adversarial_loss: 0.0559
# Epoch 973/1000
# 11/11 [==============================] - 4s 349ms/step - loss: 0.1202 - sparse_categorical_crossentropy: 0.0614 - sparse_categorical_accuracy: 0.9762 - scaled_adversarial_loss: 0.0588 - val_loss: 0.1825 - val_sparse_categorical_crossentropy: 0.1239 - val_sparse_categorical_accuracy: 0.9584 - val_scaled_adversarial_loss: 0.0587
# Epoch 974/1000
# 11/11 [==============================] - 4s 350ms/step - loss: 0.1088 - sparse_categorical_crossentropy: 0.0543 - sparse_categorical_accuracy: 0.9792 - scaled_adversarial_loss: 0.0545 - val_loss: 0.1771 - val_sparse_categorical_crossentropy: 0.1155 - val_sparse_categorical_accuracy: 0.9613 - val_scaled_adversarial_loss: 0.0616
# Epoch 975/1000
# 11/11 [==============================] - 4s 350ms/step - loss: 0.1145 - sparse_categorical_crossentropy: 0.0543 - sparse_categorical_accuracy: 0.9827 - scaled_adversarial_loss: 0.0602 - val_loss: 0.1689 - val_sparse_categorical_crossentropy: 0.1094 - val_sparse_categorical_accuracy: 0.9613 - val_scaled_adversarial_loss: 0.0596
# Epoch 976/1000
# 11/11 [==============================] - 4s 362ms/step - loss: 0.1111 - sparse_categorical_crossentropy: 0.0534 - sparse_categorical_accuracy: 0.9797 - scaled_adversarial_loss: 0.0577 - val_loss: 0.1763 - val_sparse_categorical_crossentropy: 0.1134 - val_sparse_categorical_accuracy: 0.9613 - val_scaled_adversarial_loss: 0.0629
# Epoch 977/1000
# 11/11 [==============================] - 4s 363ms/step - loss: 0.1121 - sparse_categorical_crossentropy: 0.0494 - sparse_categorical_accuracy: 0.9840 - scaled_adversarial_loss: 0.0627 - val_loss: 0.2074 - val_sparse_categorical_crossentropy: 0.1330 - val_sparse_categorical_accuracy: 0.9584 - val_scaled_adversarial_loss: 0.0744
# Epoch 978/1000
# 11/11 [==============================] - 4s 359ms/step - loss: 0.1140 - sparse_categorical_crossentropy: 0.0564 - sparse_categorical_accuracy: 0.9825 - scaled_adversarial_loss: 0.0577 - val_loss: 0.1896 - val_sparse_categorical_crossentropy: 0.1187 - val_sparse_categorical_accuracy: 0.9613 - val_scaled_adversarial_loss: 0.0709
# Epoch 979/1000
# 11/11 [==============================] - 4s 351ms/step - loss: 0.1129 - sparse_categorical_crossentropy: 0.0553 - sparse_categorical_accuracy: 0.9814 - scaled_adversarial_loss: 0.0576 - val_loss: 0.2065 - val_sparse_categorical_crossentropy: 0.1345 - val_sparse_categorical_accuracy: 0.9621 - val_scaled_adversarial_loss: 0.0721
# Epoch 980/1000
# 11/11 [==============================] - 4s 353ms/step - loss: 0.1123 - sparse_categorical_crossentropy: 0.0517 - sparse_categorical_accuracy: 0.9821 - scaled_adversarial_loss: 0.0607 - val_loss: 0.1824 - val_sparse_categorical_crossentropy: 0.1216 - val_sparse_categorical_accuracy: 0.9628 - val_scaled_adversarial_loss: 0.0608
# Epoch 981/1000
# 11/11 [==============================] - 4s 353ms/step - loss: 0.1105 - sparse_categorical_crossentropy: 0.0529 - sparse_categorical_accuracy: 0.9801 - scaled_adversarial_loss: 0.0577 - val_loss: 0.1754 - val_sparse_categorical_crossentropy: 0.1125 - val_sparse_categorical_accuracy: 0.9636 - val_scaled_adversarial_loss: 0.0630
# Epoch 982/1000
# 11/11 [==============================] - 4s 398ms/step - loss: 0.1157 - sparse_categorical_crossentropy: 0.0544 - sparse_categorical_accuracy: 0.9818 - scaled_adversarial_loss: 0.0613 - val_loss: 0.1605 - val_sparse_categorical_crossentropy: 0.1068 - val_sparse_categorical_accuracy: 0.9606 - val_scaled_adversarial_loss: 0.0537
# Epoch 983/1000
# 11/11 [==============================] - 4s 390ms/step - loss: 0.1202 - sparse_categorical_crossentropy: 0.0611 - sparse_categorical_accuracy: 0.9758 - scaled_adversarial_loss: 0.0591 - val_loss: 0.1583 - val_sparse_categorical_crossentropy: 0.1060 - val_sparse_categorical_accuracy: 0.9628 - val_scaled_adversarial_loss: 0.0522
# Epoch 984/1000
# 11/11 [==============================] - 4s 387ms/step - loss: 0.1130 - sparse_categorical_crossentropy: 0.0535 - sparse_categorical_accuracy: 0.9807 - scaled_adversarial_loss: 0.0595 - val_loss: 0.1691 - val_sparse_categorical_crossentropy: 0.1121 - val_sparse_categorical_accuracy: 0.9591 - val_scaled_adversarial_loss: 0.0570
# Epoch 985/1000
# 11/11 [==============================] - 4s 365ms/step - loss: 0.1136 - sparse_categorical_crossentropy: 0.0544 - sparse_categorical_accuracy: 0.9801 - scaled_adversarial_loss: 0.0592 - val_loss: 0.1828 - val_sparse_categorical_crossentropy: 0.1251 - val_sparse_categorical_accuracy: 0.9599 - val_scaled_adversarial_loss: 0.0577
# Epoch 986/1000
# 11/11 [==============================] - 4s 360ms/step - loss: 0.1111 - sparse_categorical_crossentropy: 0.0541 - sparse_categorical_accuracy: 0.9808 - scaled_adversarial_loss: 0.0570 - val_loss: 0.1732 - val_sparse_categorical_crossentropy: 0.1128 - val_sparse_categorical_accuracy: 0.9643 - val_scaled_adversarial_loss: 0.0604
# Epoch 987/1000
# 11/11 [==============================] - 4s 374ms/step - loss: 0.1129 - sparse_categorical_crossentropy: 0.0573 - sparse_categorical_accuracy: 0.9801 - scaled_adversarial_loss: 0.0556 - val_loss: 0.1687 - val_sparse_categorical_crossentropy: 0.1104 - val_sparse_categorical_accuracy: 0.9599 - val_scaled_adversarial_loss: 0.0584
# Epoch 988/1000
# 11/11 [==============================] - 4s 365ms/step - loss: 0.1074 - sparse_categorical_crossentropy: 0.0458 - sparse_categorical_accuracy: 0.9833 - scaled_adversarial_loss: 0.0616 - val_loss: 0.1753 - val_sparse_categorical_crossentropy: 0.1163 - val_sparse_categorical_accuracy: 0.9643 - val_scaled_adversarial_loss: 0.0590
# Epoch 989/1000
# 11/11 [==============================] - 4s 356ms/step - loss: 0.1190 - sparse_categorical_crossentropy: 0.0575 - sparse_categorical_accuracy: 0.9810 - scaled_adversarial_loss: 0.0614 - val_loss: 0.1809 - val_sparse_categorical_crossentropy: 0.1134 - val_sparse_categorical_accuracy: 0.9628 - val_scaled_adversarial_loss: 0.0675
# Epoch 990/1000
# 11/11 [==============================] - 4s 357ms/step - loss: 0.1147 - sparse_categorical_crossentropy: 0.0542 - sparse_categorical_accuracy: 0.9831 - scaled_adversarial_loss: 0.0605 - val_loss: 0.1891 - val_sparse_categorical_crossentropy: 0.1228 - val_sparse_categorical_accuracy: 0.9576 - val_scaled_adversarial_loss: 0.0663
# Epoch 991/1000
# 11/11 [==============================] - 4s 355ms/step - loss: 0.1158 - sparse_categorical_crossentropy: 0.0548 - sparse_categorical_accuracy: 0.9808 - scaled_adversarial_loss: 0.0610 - val_loss: 0.1697 - val_sparse_categorical_crossentropy: 0.1085 - val_sparse_categorical_accuracy: 0.9628 - val_scaled_adversarial_loss: 0.0612
# Epoch 992/1000
# 11/11 [==============================] - 4s 361ms/step - loss: 0.1111 - sparse_categorical_crossentropy: 0.0528 - sparse_categorical_accuracy: 0.9816 - scaled_adversarial_loss: 0.0583 - val_loss: 0.1724 - val_sparse_categorical_crossentropy: 0.1153 - val_sparse_categorical_accuracy: 0.9606 - val_scaled_adversarial_loss: 0.0571
# Epoch 993/1000
# 11/11 [==============================] - 4s 379ms/step - loss: 0.1145 - sparse_categorical_crossentropy: 0.0531 - sparse_categorical_accuracy: 0.9831 - scaled_adversarial_loss: 0.0614 - val_loss: 0.1874 - val_sparse_categorical_crossentropy: 0.1208 - val_sparse_categorical_accuracy: 0.9599 - val_scaled_adversarial_loss: 0.0666
# Epoch 994/1000
# 11/11 [==============================] - 4s 367ms/step - loss: 0.1115 - sparse_categorical_crossentropy: 0.0532 - sparse_categorical_accuracy: 0.9812 - scaled_adversarial_loss: 0.0583 - val_loss: 0.1779 - val_sparse_categorical_crossentropy: 0.1172 - val_sparse_categorical_accuracy: 0.9643 - val_scaled_adversarial_loss: 0.0607
# Epoch 995/1000
# 11/11 [==============================] - 4s 359ms/step - loss: 0.1078 - sparse_categorical_crossentropy: 0.0493 - sparse_categorical_accuracy: 0.9831 - scaled_adversarial_loss: 0.0586 - val_loss: 0.1781 - val_sparse_categorical_crossentropy: 0.1242 - val_sparse_categorical_accuracy: 0.9599 - val_scaled_adversarial_loss: 0.0539
# Epoch 996/1000
# 11/11 [==============================] - 4s 352ms/step - loss: 0.1099 - sparse_categorical_crossentropy: 0.0525 - sparse_categorical_accuracy: 0.9812 - scaled_adversarial_loss: 0.0574 - val_loss: 0.1795 - val_sparse_categorical_crossentropy: 0.1219 - val_sparse_categorical_accuracy: 0.9591 - val_scaled_adversarial_loss: 0.0576
# Epoch 997/1000
# 11/11 [==============================] - 4s 371ms/step - loss: 0.1087 - sparse_categorical_crossentropy: 0.0503 - sparse_categorical_accuracy: 0.9829 - scaled_adversarial_loss: 0.0584 - val_loss: 0.1840 - val_sparse_categorical_crossentropy: 0.1245 - val_sparse_categorical_accuracy: 0.9621 - val_scaled_adversarial_loss: 0.0595
# Epoch 998/1000
# 11/11 [==============================] - 4s 362ms/step - loss: 0.1157 - sparse_categorical_crossentropy: 0.0566 - sparse_categorical_accuracy: 0.9801 - scaled_adversarial_loss: 0.0591 - val_loss: 0.1908 - val_sparse_categorical_crossentropy: 0.1288 - val_sparse_categorical_accuracy: 0.9599 - val_scaled_adversarial_loss: 0.0620
# Epoch 999/1000
# 11/11 [==============================] - 4s 348ms/step - loss: 0.1198 - sparse_categorical_crossentropy: 0.0612 - sparse_categorical_accuracy: 0.9790 - scaled_adversarial_loss: 0.0585 - val_loss: 0.1767 - val_sparse_categorical_crossentropy: 0.1180 - val_sparse_categorical_accuracy: 0.9613 - val_scaled_adversarial_loss: 0.0587
# Epoch 1000/1000
# 11/11 [==============================] - 4s 386ms/step - loss: 0.1104 - sparse_categorical_crossentropy: 0.0508 - sparse_categorical_accuracy: 0.9849 - scaled_adversarial_loss: 0.0597 - val_loss: 0.1773 - val_sparse_categorical_crossentropy: 0.1226 - val_sparse_categorical_accuracy: 0.9576 - val_scaled_adversarial_loss: 0.0547

# %%
adv_model.evaluate({'feature': X_test, 'label': y_test}, batch_size=1)
# Out:
# 1345/1345 [==============================] - 10s 7ms/step - loss: 0.1754 - sparse_categorical_crossentropy: 0.1199 - sparse_categorical_accuracy: 0.9576 - scaled_adversarial_loss: 0.0555
# [0.17542530596256256,
#  0.11988432705402374,
#  0.9576207995414734,
#  0.05554082989692688]
